# %% [markdown]
# # WE ARE NOW WORKING ON DATASET CLASS 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud


# Load the CSV file into a DataFrame
df = pd.read_csv("C://Users//shree//Desktop//VIT AP//Capstone//PROJECT//DATA SET//1_TrainingSet_2Class.csv")
print(df.head()) 
print(df.info())
# Out:
#    1  s887067566329536512  \
# 0  0  s898251156299927553
# 1  0  s880911328117915648
# 2  0  s902182178158776321
# 3  0  s902816102794878976
# 4  0  s902910459740815360
#
#   Disabled Vehicle on Westbound highway WB at Emily Drive.\n\nUse caution when traveling through this area.
# 0  New Teacher Lunch &amp; training! Marker wars ...
# 1  And the  spot in our #uhaultrends Canadian Des...
# 2   years ago today #MLK gave his historic "I Hav...
# 3   Aww it’s always hard to say goodbye! 😢 What’s...
# 4   DO NOT PAY North Korea another single PENNY! ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40878 entries, 0 to 40877
# Data columns (total 3 columns):
#  #   Column                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                   --------------  -----
# ...

# %%
df = df.iloc[:, 2:] 
df.head()
# Out:
#   Disabled Vehicle on Westbound highway WB at Emily Drive.\n\nUse caution when traveling through this area.
# 0  New Teacher Lunch &amp; training! Marker wars ...
# 1  And the  spot in our #uhaultrends Canadian Des...
# 2   years ago today #MLK gave his historic "I Hav...
# 3   Aww it’s always hard to say goodbye! 😢 What’s...
# 4   DO NOT PAY North Korea another single PENNY! ...

# %%
column_names = ['tweets']
df.columns=column_names
df.head
# Out:
# <bound method NDFrame.head of                                                   tweets
# 0      New Teacher Lunch &amp; training! Marker wars ...
# 1      And the  spot in our #uhaultrends Canadian Des...
# 2       years ago today #MLK gave his historic "I Hav...
# 3       Aww it’s always hard to say goodbye! 😢 What’s...
# 4       DO NOT PAY North Korea another single PENNY! ...
# ...                                                  ...
# 40873  #WinnebagoCounty, two left northbound lanes on...
# 40874  Updated: Crash in Lee on highway north beyond ...
# 40875   Glad to hear our staff is treating you so wel...
# 40876  UD: Fire (Highrise Residential) - Kipling Aven...
# 40877  Starts this week Committee on the Rights of Pe...
#
# [40878 rows x 1 columns]>

# %%
df.shape
# Out:
# (40878, 1)

# %%
tweets = df['tweets']

# Word Cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(tweets))
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Tweets')
plt.show()

# Bar plot of top N frequent words
from collections import Counter
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
words = ' '.join(tweets).lower()
word_tokens = word_tokenize(words)
filtered_words = [word for word in word_tokens if word.isalnum() and word not in stop_words]
word_freq = Counter(filtered_words)

top_n = 50
top_words = [word[0] for word in word_freq.most_common(top_n)]
top_word_counts = [word[1] for word in word_freq.most_common(top_n)]

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=top_word_counts, y=top_words)
plt.title(f'Top {top_n} Most Frequent Words in Tweets')
plt.xlabel('Frequency')
plt.ylabel('Word')
plt.show()

# Additional plots (you can customize these based on your needs)
# For example:
# - Histogram of tweet lengths
# - Sentiment analysis distribution
# - Time series analysis of tweet volume

# Don't forget to install the necessary packages if you haven't already:
# pip install pandas matplotlib seaborn nltk wordcloud

# %%
df['tweet_length'] = df['tweets'].apply(len)
#here we will calculate the tweet length and then add another column which shows the length of each tweet.

print(df.head())
# Out:
#                                               tweets  tweet_length
# 0  New Teacher Lunch &amp; training! Marker wars ...           104
# 1  And the  spot in our #uhaultrends Canadian Des...            95
# 2   years ago today #MLK gave his historic "I Hav...            84
# 3   Aww it’s always hard to say goodbye! 😢 What’s...            88
# 4   DO NOT PAY North Korea another single PENNY! ...           101

# %%
import matplotlib.pyplot as plt

# Create a histogram of tweet lengths
plt.figure(figsize=(10, 6))
plt.hist(df['tweet_length'], bins=20, color='blue', alpha=0.7)
plt.title('Histogram of Tweet Lengths')
plt.xlabel('Tweet Length')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
from textblob import TextBlob
# Function to get sentiment polarity using TextBlob
def get_sentiment(text):
    analysis = TextBlob(text)
    return analysis.sentiment.polarity

# Apply sentiment analysis to each tweet and create a new column
df['sentiment'] = df['tweets'].apply(get_sentiment)

# Display the updated DataFrame
print(df.head())
# Out:
#                                               tweets  tweet_length  sentiment
# 0  New Teacher Lunch &amp; training! Marker wars ...           104   0.213068
# 1  And the  spot in our #uhaultrends Canadian Des...            95   0.000000
# 2   years ago today #MLK gave his historic "I Hav...            84   0.000000
# 3   Aww it’s always hard to say goodbye! 😢 What’s...            88   0.145139
# 4   DO NOT PAY North Korea another single PENNY! ...           101  -0.089286

# %%
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df['sentiment'], bins=20, color='green', kde=True)
plt.title('Sentiment Analysis Distribution')
plt.xlabel('Sentiment Score')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# # NOW WE WORK ON CLASS 3 OF THE DATASET

# %%
df2 = pd.read_csv("C://Users//shree//Desktop//VIT AP//Capstone//PROJECT//DATA SET//1_TrainingSet_3Class.csv")
print(df2.head()) 
print(df2.info())
# Out:
#    2  s801810168862408705  \
# 0  0  s899723031702065152
# 1  0  s840600120727130112
# 2  1  s900335719461400580
# 3  0  s657684246153314304
# 4  0  s872960543077928962
#
#   UPDATE: Rt. in York County has reopened near Commerce Circle. Detour lifted.
# 0  #Fargo #ND #USA - Sr. Clinical Research Associ...
# 1  Just two of the biggest fans riding the ride i...
# 2  Wreck on Southbound just north of Atlanta High...
# 3  Justin bieber's new album is going to be amazi...
# 4  Next up is the Sr. Manager of Football Develop...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40941 entries, 0 to 40940
# Data columns (total 3 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   2                                                                             40941 non-null  int64
# ...

# %%
df2 = df2.iloc[:, 2:] 
df2.head()
# Out:
#   UPDATE: Rt. in York County has reopened near Commerce Circle. Detour lifted.
# 0  #Fargo #ND #USA - Sr. Clinical Research Associ...
# 1  Just two of the biggest fans riding the ride i...
# 2  Wreck on Southbound just north of Atlanta High...
# 3  Justin bieber's new album is going to be amazi...
# 4  Next up is the Sr. Manager of Football Develop...

# %%
column_names = ['tweets']
df2.columns=column_names
df2.head
# Out:
# <bound method NDFrame.head of                                                   tweets
# 0      #Fargo #ND #USA - Sr. Clinical Research Associ...
# 1      Just two of the biggest fans riding the ride i...
# 2      Wreck on Southbound just north of Atlanta High...
# 3      Justin bieber's new album is going to be amazi...
# 4      Next up is the Sr. Manager of Football Develop...
# ...                                                  ...
# 40936  Start beach-bonfire-BBQ season off right with ...
# 40937  Snow quickly covering roads in the southern co...
# 40938  Updated: Crash in Duval on highway east at Exi...
# 40939  Join the Truth Team and help set the record st...
# 40940   Work is already underway to complete the remo...
#
# [40941 rows x 1 columns]>

# %%
df2.shape
# Out:
# (40941, 1)

# %%
tweets = df2['tweets']

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(tweets))
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Tweets')
plt.show()

# %%
from collections import Counter
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
words = ' '.join(tweets).lower()
word_tokens = word_tokenize(words)
filtered_words = [word for word in word_tokens if word.isalnum() and word not in stop_words]
word_freq = Counter(filtered_words)

top_n = 30
top_words = [word[0] for word in word_freq.most_common(top_n)]
top_word_counts = [word[1] for word in word_freq.most_common(top_n)]

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=top_word_counts, y=top_words)
plt.title(f'Top {top_n} Most Frequent Words in Tweets')
plt.xlabel('Frequency')
plt.ylabel('Word')
plt.show()

# %%
df2['tweet_length'] = df2['tweets'].apply(len)
#here we will calculate the tweet length and then add another column which shows the length of each tweet.

print(df2.head())
# Out:
#                                               tweets  tweet_length
# 0  #Fargo #ND #USA - Sr. Clinical Research Associ...           115
# 1  Just two of the biggest fans riding the ride i...            73
# 2  Wreck on Southbound just north of Atlanta High...           129
# 3  Justin bieber's new album is going to be amazi...            50
# 4  Next up is the Sr. Manager of Football Develop...           103

# %%
import matplotlib.pyplot as plt

# Create a histogram of tweet lengths
plt.figure(figsize=(10, 6))
plt.hist(df2['tweet_length'], bins=20, color='coral', alpha=0.7)
plt.title('Histogram of Tweet Lengths')
plt.xlabel('Tweet Length')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
from textblob import TextBlob
# Function to get sentiment polarity using TextBlob
def get_sentiment(text):
    analysis = TextBlob(text)
    return analysis.sentiment.polarity

# Apply sentiment analysis to each tweet and create a new column
df2['sentiment'] = df2['tweets'].apply(get_sentiment)

# Display the updated DataFrame
print(df2.head())
# Out:
#                                               tweets  tweet_length  sentiment
# 0  #Fargo #ND #USA - Sr. Clinical Research Associ...           115   0.000000
# 1  Just two of the biggest fans riding the ride i...            73   0.000000
# 2  Wreck on Southbound just north of Atlanta High...           129  -0.033333
# 3  Justin bieber's new album is going to be amazi...            50   0.368182
# 4  Next up is the Sr. Manager of Football Develop...           103   0.000000

# %%
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df2['sentiment'], bins=20, color='teal', kde=True)
plt.title('Sentiment Analysis Distribution')
plt.xlabel('Sentiment Score')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
